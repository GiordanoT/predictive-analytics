# %%
import pandas as pd
from pathlib import Path

# %%
# Defining initial parameters
units = ['T', 'RA', 'LA', 'RL', 'LL']
sensors = ['A', 'G', 'M']
coordinates = ['x', 'y', 'z']
segments = 60
subjects = 8
activities = 19

# %%
# Building columns (for each unit we have 3 sensors (A, G, M), each sensor capture values that refer to 3 coordinates (x, y, z)).
names = []
for unit in units:
    for sensor in sensors:
        for coordinate in coordinates:
            names.append(f'{unit}({sensor}, {coordinate})')
names
# Out:
# ['T(A, x)',
#  'T(A, y)',
#  'T(A, z)',
#  'T(G, x)',
#  'T(G, y)',
#  'T(G, z)',
#  'T(M, x)',
#  'T(M, y)',
#  'T(M, z)',
#  'RA(A, x)',
#  'RA(A, y)',
#  'RA(A, z)',
#  'RA(G, x)',
#  'RA(G, y)',
#  'RA(G, z)',
#  'RA(M, x)',
#  'RA(M, y)',
#  'RA(M, z)',
#  'LA(A, x)',
#  'LA(A, y)',
#  'LA(A, z)',
#  'LA(G, x)',
#  'LA(G, y)',
#  'LA(G, z)',
#  'LA(M, x)',
#  'LA(M, y)',
#  'LA(M, z)',
#  'RL(A, x)',
#  'RL(A, y)',
#  'RL(A, z)',
#  'RL(G, x)',
#  'RL(G, y)',
#  'RL(G, z)',
#  'RL(M, x)',
#  'RL(M, y)',
#  'RL(M, z)',
#  'LL(A, x)',
#  'LL(A, y)',
#  'LL(A, z)',
#  'LL(G, x)',
#  'LL(G, y)',
#  'LL(G, z)',
#  'LL(M, x)',
#  'LL(M, y)',
#  'LL(M, z)']

# %%
df = pd.DataFrame()

# %%
# Building a unique dataframe using all data in folders (activity > subject > segment).
for activity in range(1, activities + 1):
    for subject in range(1, subjects + 1):
        print(f'Building DF: activity = {activity} and subject = {subject}')
        for segment in range(1, segments + 1):
            sos_df = pd.read_csv(f'data/a{activity:02d}/p{subject}/s{segment:02d}.txt', sep=',', names=names)
            sos_df['Subject'] = subject
            sos_df['Activity'] = activity
            df = pd.concat([df, sos_df], ignore_index=True)
# Out:
# Building DF: activity = 1 and subject = 1
# Building DF: activity = 1 and subject = 2
# Building DF: activity = 1 and subject = 3
# Building DF: activity = 1 and subject = 4
# Building DF: activity = 1 and subject = 5
# Building DF: activity = 1 and subject = 6
# Building DF: activity = 1 and subject = 7
# Building DF: activity = 1 and subject = 8
# Building DF: activity = 2 and subject = 1
# Building DF: activity = 2 and subject = 2
# Building DF: activity = 2 and subject = 3
# Building DF: activity = 2 and subject = 4
# Building DF: activity = 2 and subject = 5
# Building DF: activity = 2 and subject = 6
# Building DF: activity = 2 and subject = 7
# Building DF: activity = 2 and subject = 8
# Building DF: activity = 3 and subject = 1
# Building DF: activity = 3 and subject = 2
# Building DF: activity = 3 and subject = 3
# Building DF: activity = 3 and subject = 4
# Building DF: activity = 3 and subject = 5
# Building DF: activity = 3 and subject = 6
# Building DF: activity = 3 and subject = 7
# Building DF: activity = 3 and subject = 8
# Building DF: activity = 4 and subject = 1
# Building DF: activity = 4 and subject = 2
# Building DF: activity = 4 and subject = 3
# Building DF: activity = 4 and subject = 4
# Building DF: activity = 4 and subject = 5
# Building DF: activity = 4 and subject = 6
# Building DF: activity = 4 and subject = 7
# Building DF: activity = 4 and subject = 8
# Building DF: activity = 5 and subject = 1
# Building DF: activity = 5 and subject = 2
# Building DF: activity = 5 and subject = 3
# Building DF: activity = 5 and subject = 4
# Building DF: activity = 5 and subject = 5
# Building DF: activity = 5 and subject = 6
# Building DF: activity = 5 and subject = 7
# Building DF: activity = 5 and subject = 8
# Building DF: activity = 6 and subject = 1
# Building DF: activity = 6 and subject = 2
# Building DF: activity = 6 and subject = 3
# Building DF: activity = 6 and subject = 4
# Building DF: activity = 6 and subject = 5
# Building DF: activity = 6 and subject = 6
# Building DF: activity = 6 and subject = 7
# Building DF: activity = 6 and subject = 8
# Building DF: activity = 7 and subject = 1
# Building DF: activity = 7 and subject = 2
# Building DF: activity = 7 and subject = 3
# Building DF: activity = 7 and subject = 4
# Building DF: activity = 7 and subject = 5
# Building DF: activity = 7 and subject = 6
# Building DF: activity = 7 and subject = 7
# Building DF: activity = 7 and subject = 8
# Building DF: activity = 8 and subject = 1
# Building DF: activity = 8 and subject = 2
# Building DF: activity = 8 and subject = 3
# Building DF: activity = 8 and subject = 4
# Building DF: activity = 8 and subject = 5
# Building DF: activity = 8 and subject = 6
# Building DF: activity = 8 and subject = 7
# Building DF: activity = 8 and subject = 8
# Building DF: activity = 9 and subject = 1
# Building DF: activity = 9 and subject = 2
# Building DF: activity = 9 and subject = 3
# Building DF: activity = 9 and subject = 4
# Building DF: activity = 9 and subject = 5
# Building DF: activity = 9 and subject = 6
# Building DF: activity = 9 and subject = 7
# Building DF: activity = 9 and subject = 8
# Building DF: activity = 10 and subject = 1
# Building DF: activity = 10 and subject = 2
# Building DF: activity = 10 and subject = 3
# Building DF: activity = 10 and subject = 4
# Building DF: activity = 10 and subject = 5
# Building DF: activity = 10 and subject = 6
# Building DF: activity = 10 and subject = 7
# Building DF: activity = 10 and subject = 8
# Building DF: activity = 11 and subject = 1
# Building DF: activity = 11 and subject = 2
# Building DF: activity = 11 and subject = 3
# Building DF: activity = 11 and subject = 4
# Building DF: activity = 11 and subject = 5
# Building DF: activity = 11 and subject = 6
# Building DF: activity = 11 and subject = 7
# Building DF: activity = 11 and subject = 8
# Building DF: activity = 12 and subject = 1
# Building DF: activity = 12 and subject = 2
# Building DF: activity = 12 and subject = 3
# Building DF: activity = 12 and subject = 4
# Building DF: activity = 12 and subject = 5
# Building DF: activity = 12 and subject = 6
# Building DF: activity = 12 and subject = 7
# Building DF: activity = 12 and subject = 8
# Building DF: activity = 13 and subject = 1
# Building DF: activity = 13 and subject = 2
# Building DF: activity = 13 and subject = 3
# Building DF: activity = 13 and subject = 4
# Building DF: activity = 13 and subject = 5
# Building DF: activity = 13 and subject = 6
# Building DF: activity = 13 and subject = 7
# Building DF: activity = 13 and subject = 8
# Building DF: activity = 14 and subject = 1
# Building DF: activity = 14 and subject = 2
# Building DF: activity = 14 and subject = 3
# Building DF: activity = 14 and subject = 4
# Building DF: activity = 14 and subject = 5
# Building DF: activity = 14 and subject = 6
# Building DF: activity = 14 and subject = 7
# Building DF: activity = 14 and subject = 8
# Building DF: activity = 15 and subject = 1
# Building DF: activity = 15 and subject = 2
# Building DF: activity = 15 and subject = 3
# Building DF: activity = 15 and subject = 4
# Building DF: activity = 15 and subject = 5
# Building DF: activity = 15 and subject = 6
# Building DF: activity = 15 and subject = 7
# Building DF: activity = 15 and subject = 8
# Building DF: activity = 16 and subject = 1
# Building DF: activity = 16 and subject = 2
# Building DF: activity = 16 and subject = 3
# Building DF: activity = 16 and subject = 4
# Building DF: activity = 16 and subject = 5
# Building DF: activity = 16 and subject = 6
# Building DF: activity = 16 and subject = 7
# Building DF: activity = 16 and subject = 8
# Building DF: activity = 17 and subject = 1
# Building DF: activity = 17 and subject = 2
# Building DF: activity = 17 and subject = 3
# Building DF: activity = 17 and subject = 4
# Building DF: activity = 17 and subject = 5
# Building DF: activity = 17 and subject = 6
# Building DF: activity = 17 and subject = 7
# Building DF: activity = 17 and subject = 8
# Building DF: activity = 18 and subject = 1
# Building DF: activity = 18 and subject = 2
# Building DF: activity = 18 and subject = 3
# Building DF: activity = 18 and subject = 4
# Building DF: activity = 18 and subject = 5
# Building DF: activity = 18 and subject = 6
# Building DF: activity = 18 and subject = 7
# Building DF: activity = 18 and subject = 8
# Building DF: activity = 19 and subject = 1
# Building DF: activity = 19 and subject = 2
# Building DF: activity = 19 and subject = 3
# Building DF: activity = 19 and subject = 4
# Building DF: activity = 19 and subject = 5
# Building DF: activity = 19 and subject = 6
# Building DF: activity = 19 and subject = 7
# Building DF: activity = 19 and subject = 8

# %%
# Saving the dataframe, so we can easly use it.
filepath = Path('activities.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath, sep=';')
