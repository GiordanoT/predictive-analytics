# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('activities_cleaned.csv', sep=';', index_col=0)
df
# Out:
#          Activity  Subject     ACC x     ACC y     ACC z     GYR x     GYR y  \
# 0               1        1   5.92767  -1.65370  18.95477 -0.006238 -0.015878
# 1               1        1   5.92959  -1.74260  18.89768 -0.011134  0.002558
# 2               1        1   5.92739  -1.71680  18.90550  0.014435  0.011941
# 3               1        1   5.98639  -1.70500  18.84810  0.018648  0.041053
# 4               1        1   5.97912  -1.69180  18.85393 -0.017254  0.019668
# ...           ...      ...       ...       ...       ...       ...       ...
# 1139994        19        8  -7.48100  -1.32740   0.10600  5.342700 -2.735840
# 1139995        19        8 -15.16100  11.03850 -20.12750  5.554180  1.227394
# 1139996        19        8 -21.30240  32.25714  10.33298  6.908930  0.749020
# 1139998        19        8  -2.37223  39.58631  -5.41944  3.860440  3.559620
# 1139999        19        8  -4.92589  34.61402  16.70087  1.148010  1.892284
#
#             GYR z    MAG x     MAG y     MAG z
# 0       -0.038254 -0.53764 -0.240494 -0.075594
# 1       -0.015154 -0.53752 -0.233245 -0.071104
# 2       -0.016073 -0.53973 -0.237137 -0.075123
# 3        0.000366 -0.56724 -0.246849 -0.105868
# 4       -0.001110 -0.53635 -0.238626 -0.070397
# ...           ...      ...       ...       ...
# 1139994 -0.338210  0.68606 -0.359100 -0.080237
# 1139995  0.622390  0.53623 -0.023682 -0.006403
# 1139996 -0.843757  0.37812  0.366600  0.084995
# 1139998 -2.401520  0.15107  0.572670 -0.154697
# 1139999 -5.494600  0.11290  0.407180 -0.081932
#
# [1130028 rows x 11 columns]

# %%
# Drawing the distribution.
# %matplotlib inline
df.hist(column=['ACC x', 'ACC y', 'ACC z'], figsize=(7, 5))
df.hist(column=['GYR x', 'GYR y', 'GYR z'], figsize=(7, 5))
df.hist(column=['MAG x', 'MAG y', 'MAG z'], figsize=(7, 5))
# Out:
# array([[<Axes: title={'center': 'MAG x'}>,
#         <Axes: title={'center': 'MAG y'}>],
#        [<Axes: title={'center': 'MAG z'}>, <Axes: >]], dtype=object)

# %%
# Drawing the boxplot.
# %matplotlib inline
df.boxplot(column=['ACC x', 'ACC y', 'ACC z'], figsize=(10, 5))
# Out:
# <Axes: >

# %%
# Drawing the boxplot.
# %matplotlib inline
df.boxplot(column=['GYR x', 'GYR y', 'GYR z'], figsize=(10, 5))
# Out:
# <Axes: >

# %%
# Drawing the boxplot.
# %matplotlib inline
df.boxplot(column=['MAG x', 'MAG y', 'MAG z'], figsize=(10, 5))
# Out:
# <Axes: >

# %%
# Drawing the Correlation Matrix.
corr_matrix = df.drop(columns=['Activity', 'Subject']).corr()
sn.heatmap(corr_matrix, annot=False)
plt.show()

# %%
df.describe()
# Out:
#            Activity       Subject         ACC x         ACC y         ACC z  \
# count  1.130028e+06  1.130028e+06  1.130028e+06  1.130028e+06  1.130028e+06
# mean   9.945545e+00  4.497381e+00  1.606281e+00 -2.841606e-01  7.685759e+00
# std    5.461826e+00  2.289162e+00  1.068828e+01  8.093096e+00  8.370899e+00
# min    1.000000e+00  1.000000e+00 -4.998880e+01 -4.999650e+01 -4.997340e+01
# 25%    5.000000e+00  3.000000e+00 -5.005660e+00 -3.409850e+00  2.485097e+00
# 50%    1.000000e+01  4.000000e+00  3.382025e+00 -1.445800e-01  6.828299e+00
# 75%    1.500000e+01  6.000000e+00  7.964000e+00  3.279270e+00  1.294110e+01
# max    1.900000e+01  8.000000e+00  4.999300e+01  4.998373e+01  4.999230e+01
#
#               GYR x         GYR y         GYR z         MAG x         MAG y  \
# count  1.130028e+06  1.130028e+06  1.130028e+06  1.130028e+06  1.130028e+06
# mean   4.019571e-03  4.020330e-02 -1.248109e-02 -2.062514e-01  8.541134e-02
# std    1.970359e+00  1.329502e+00  2.042505e+00  8.555909e-01  7.972194e-01
# min   -9.999880e+00 -9.991483e+00 -9.995452e+00 -3.443709e+00 -2.715100e+00
# 25%   -6.534847e-01 -3.099555e-01 -7.013018e-01 -7.665600e-01 -4.516013e-01
# 50%    4.166000e-03  2.251950e-02 -1.805150e-02 -3.617300e-01  4.777200e-02
# 75%    6.783812e-01  4.473310e-01  6.877122e-01  2.501000e-01  6.573125e-01
# max    9.999740e+00  9.994360e+00  9.997920e+00  4.685390e+00  3.362810e+00
#
#               MAG z
# count  1.130028e+06
# mean  -7.437241e-01
# std    9.143628e-01
# min   -4.716000e+00
# 25%   -1.459504e+00
# 50%   -7.263075e-01
# 75%   -4.805925e-02
# max    3.139322e+00
