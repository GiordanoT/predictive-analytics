# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('activities_cleaned.csv', sep=';', index_col=0)
df = df.sample(frac=1).reset_index(drop=True)
df = df[0:40000]
df
# Out:
#        Activity  Subject     ACC x      ACC y     ACC z     GYR x     GYR y  \
# 0             7        6   7.90160   2.241659   6.85237  0.039673  0.026556
# 1             9        4  14.36770 -15.096000  13.24892  0.088090 -0.524351
# 2            18        6   3.80540  -3.158040  -1.27260  0.455250 -2.043116
# 3             5        4  12.31200  -3.239700   6.24165 -0.526878 -0.585733
# 4            19        4   6.42670   4.797300   2.62086 -1.414257  0.412080
# ...         ...      ...       ...        ...       ...       ...       ...
# 39995        19        4  -0.98480  17.329036   8.83343 -2.838970 -5.050050
# 39996         7        5   6.99560  -0.439140   8.22546 -0.023047 -0.003816
# 39997        19        5  -7.56600 -10.773000   2.00488  1.095850  0.864985
# 39998        13        1   0.30490  -3.237640  15.13070  1.700200  0.869051
# 39999         1        8  -5.14787  -0.202510  13.30760 -0.029064  0.000018
#
#           GYR z    MAG x     MAG y     MAG z
# 0     -0.027004 -0.46674  0.166360  0.654442
# 1      0.674472 -1.17996 -0.550100  0.422139
# 2      0.332406 -0.78952  0.838500  0.552280
# 3     -0.661070 -0.14424  1.100010 -0.748330
# 4     -0.350390 -0.51639  0.195625 -0.717600
# ...         ...      ...       ...       ...
# 39995 -3.883930 -0.22804 -0.361861 -0.741990
# 39996  0.005979 -0.28429 -0.002420 -0.288117
# 39997 -2.520090  2.64015 -0.134850 -1.164330
# 39998  1.730017  0.68640  0.228260 -2.463570
# 39999 -0.133556  0.19299 -0.086340  0.013630
#
# [40000 rows x 11 columns]

# %%
# Splitting data into training and testing ones.
X = df.drop(columns=['Activity', 'Subject'])
y = df['Activity']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
# Training the model.
svm_model = SVC()
svm_model.fit(X_train, y_train)
y_predicted_train = svm_model.predict(X_train)
y_predicted_test = svm_model.predict(X_test)
training_acc = round(accuracy_score(y_train, y_predicted_train), 3)
testing_acc = round(accuracy_score(y_test, y_predicted_test), 3)

# %%
# Checking accuracy.
print(f'Training Accuracy: {training_acc}')
print(f'Testing Accuracy: {testing_acc}')
# Out:
# Training Accuracy: 0.748
# Testing Accuracy: 0.725
